# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../'))

# %%
import math
import common 
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# %%
train_df = pd.read_csv("./data/train.csv", index_col="PassengerId")
test_df = pd.read_csv("./data/test.csv", index_col="PassengerId")

# %%
train_size = train_df.shape[0]
test_size = test_df.shape[0]

# %%
combined_df = pd.concat([train_df, test_df])

# %% [markdown]
# # Generate Female + Children Related Features

# %%
def age_encoding(x):
    if x is np.nan or x is None or math.isnan(x):
        return 0
        
    elif x <= 15: 
        return 1
    elif x <= 60:
        return 2
    else:
        return 3

combined_df['AgeEncoded'] = combined_df['Age'].map(age_encoding)

# %%
def sex_encoding(x):
    if x == 'female':
        return 1
    elif x == 'male':
        return 2
    else:
        return 0
    
combined_df['SexEncoded'] = combined_df['Sex'].map(sex_encoding)

sexEncoder = OneHotEncoder(handle_unknown='ignore')
sexEncoder.fit(combined_df[['SexEncoded']])
sex_temp_df = pd.DataFrame(sexEncoder.transform(combined_df[['SexEncoded']]).toarray(), columns=sexEncoder.get_feature_names(['SexEncoded']), index=combined_df.index)

combined_df = pd.concat([combined_df, sex_temp_df], axis=1)

# %%
combined_df.head(train_size)[combined_df['Sex'] == 'male'][:5]
# Out:
# <ipython-input-13-9d5c0f0f744f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   combined_df.head(train_size)[combined_df['Sex'] == 'male'][:5]
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                 0.0       3         Braund, Mr. Owen Harris  male  22.0
# 5                 0.0       3        Allen, Mr. William Henry  male  35.0
# 6                 0.0       3                Moran, Mr. James  male   NaN
# 7                 0.0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                 0.0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked  AgeEncoded  \
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S           2
# 5                0      0     373450   8.0500   NaN        S           2
# 6                0      0     330877   8.4583   NaN        Q           0
# 7                0      0      17463  51.8625   E46        S           2
# 8                3      1     349909  21.0750   NaN        S           1
#
#              SexEncoded  SexEncoded_1  SexEncoded_2
# PassengerId
# 1                     2           0.0           1.0
# 5                     2           0.0           1.0
# 6                     2           0.0           1.0
# 7                     2           0.0           1.0
# 8                     2           0.0           1.0

# %% [markdown]
# ## generate family ID

# %%
def extract_surename(x):
    return x.split(",")[0].strip().lower()
combined_df['Surename'] = combined_df['Name'].apply(lambda x: extract_surename(x))

# %%
def get_family_id(x):
    return "{}_{}_{}".format(x['Surename'], x['Pclass'], x['Embarked'])
combined_df['Family'] = combined_df.apply(lambda x: get_family_id(x), axis=1)

# %%
combined_df['Family'].value_counts()
# Out:
# sage_3_S           11
# andersson_3_S      11
# goodwin_3_S         8
# asplund_3_S         8
# panula_3_S          6
#                    ..
# charters_3_Q        1
# morley_3_S          1
# birnbaum_1_C        1
# berglund_3_S        1
# francatelli_1_C     1
# Name: Family, Length: 915, dtype: int64

# %%
combined_df.head(train_size)[combined_df['Sex'] == 'male'].sort_values('Family')[:50]
# Out:
# <ipython-input-24-ecb569f9ec15>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   combined_df.head(train_size)[combined_df['Sex'] == 'male'].sort_values('Family')[:50]
#              Survived  Pclass                                          Name  \
# PassengerId
# 846               0.0       3                           Abbing, Mr. Anthony
# 747               0.0       3                   Abbott, Mr. Rossmore Edward
# 309               0.0       2                           Abelson, Mr. Samuel
# 366               0.0       3                Adahl, Mr. Mauritz Nils Martin
# 402               0.0       3                               Adams, Mr. John
# 208               1.0       3                   Albimona, Mr. Nassef Cassem
# 811               0.0       3                        Alexander, Mr. William
# 841               0.0       3                   Alhomaki, Mr. Ilmari Rudolf
# 785               0.0       3                              Ali, Mr. William
# 211               0.0       3                                Ali, Mr. Ahmed
# 5                 0.0       3                      Allen, Mr. William Henry
# 306               1.0       1                Allison, Master. Hudson Trevor
# 835               0.0       3                        Allum, Mr. Owen George
# 461               1.0       1                           Anderson, Mr. Harry
# 147               1.0       3  Andersson, Mr. August Edvard ("Wennerstrom")
# 851               0.0       3       Andersson, Master. Sigvard Harald Elias
# 14                0.0       3                   Andersson, Mr. Anders Johan
# 92                0.0       3                    Andreasson, Mr. Paul Edvin
# 145               0.0       2                    Andrew, Mr. Edgardo Samuel
# 807               0.0       1                        Andrews, Mr. Thomas Jr
# 354               0.0       3                     Arnold-Franchi, Mr. Josef
# 494               0.0       1                       Artagaveytia, Mr. Ramon
# 364               0.0       3                               Asim, Mr. Adola
# 262               1.0       3             Asplund, Master. Edvin Rojj Felix
# 183               0.0       3         Asplund, Master. Clarence Gustaf Hugo
# 245               0.0       3                          Attalah, Mr. Sleiman
# 834               0.0       3                        Augustsson, Mr. Albert
# 207               0.0       3                    Backstrom, Mr. Karl Alfred
# 662               0.0       3                             Badt, Mr. Mohamed
# 758               0.0       2                      Bailey, Mr. Percy Andrew
# 871               0.0       3                             Balkic, Mr. Cerin
# 884               0.0       2                 Banfield, Mr. Frederick James
# 763               1.0       3                         Barah, Mr. Hanna Assi
# 631               1.0       1          Barkworth, Mr. Algernon Henry Wilson
# 113               0.0       3                        Barton, Mr. David John
# 151               0.0       2                    Bateman, Rev. Robert James
# 169               0.0       1                           Baumann, Mr. John D
# 119               0.0       1                      Baxter, Mr. Quigg Edmond
# 544               1.0       2                             Beane, Mr. Edward
# 373               0.0       3                    Beavan, Mr. William Thomas
# 184               1.0       2                     Becker, Master. Richard F
# 249               1.0       1                 Beckwith, Mr. Richard Leonard
# 22                1.0       2                         Beesley, Mr. Lawrence
# 890               1.0       1                         Behr, Mr. Karl Howell
# 163               0.0       3                    Bengtsson, Mr. John Viktor
# 226               0.0       3                  Berglund, Mr. Karl Ivar Sven
# 734               0.0       2                    Berriman, Mr. William John
# 379               0.0       3                           Betros, Mr. Tannous
# 75                1.0       3                                 Bing, Mr. Lee
# 409               0.0       3             Birkeland, Mr. Hans Martin Monsen
#
#               Sex    Age  SibSp  Parch              Ticket      Fare Cabin  \
# PassengerId
# 846          male  42.00      0      0           C.A. 5547    7.5500     M
# 747          male  16.00      1      1           C.A. 2673   20.2500     M
# 309          male  30.00      1      0           P/PP 3381   24.0000     M
# 366          male  30.00      0      0              C 7076    7.2500     M
# 402          male  26.00      0      0              341826    8.0500     M
# 208          male  26.00      0      0                2699   18.7875     M
# 811          male  26.00      0      0                3474    7.8875     M
# 841          male  20.00      0      0    SOTON/O2 3101287    7.9250     M
# 785          male  25.00      0      0  SOTON/O.Q. 3101312    7.0500     M
# 211          male  24.00      0      0  SOTON/O.Q. 3101311    7.0500     M
# 5            male  35.00      0      0              373450    8.0500     M
# 306          male   0.92      1      2              113781  151.5500     C
# 835          male  18.00      0      0                2223    8.3000     M
# 461          male  48.00      0      0               19952   26.5500     E
# 147          male  27.00      0      0              350043    7.7958     M
# 851          male   4.00      4      2              347082   31.2750     M
# 14           male  39.00      1      5              347082   31.2750     M
# 92           male  20.00      0      0              347466    7.8542     M
# 145          male  18.00      0      0              231945   11.5000     M
# 807          male  39.00      0      0              112050    0.0000     A
# 354          male  25.00      1      0              349237   17.8000     M
# 494          male  71.00      0      0            PC 17609   49.5042     M
# 364          male  35.00      0      0  SOTON/O.Q. 3101310    7.0500     M
# 262          male   3.00      4      2              347077   31.3875     M
# 183          male   9.00      4      2              347077   31.3875     M
# 245          male  30.00      0      0                2694    7.2250     M
# 834          male  23.00      0      0              347468    7.8542     M
# 207          male  32.00      1      0             3101278   15.8500     M
# 662          male  40.00      0      0                2623    7.2250     M
# 758          male  18.00      0      0               29108   11.5000     M
# 871          male  26.00      0      0              349248    7.8958     M
# 884          male  28.00      0      0    C.A./SOTON 34068   10.5000     M
# 763          male  20.00      0      0                2663    7.2292     M
# 631          male  80.00      0      0               27042   30.0000     A
# 113          male  22.00      0      0              324669    8.0500     M
# 151          male  51.00      0      0         S.O.P. 1166   12.5250     M
# 169          male    NaN      0      0            PC 17318   25.9250     M
# 119          male  24.00      0      1            PC 17558  247.5208     B
# 544          male  32.00      1      0                2908   26.0000     M
# 373          male  19.00      0      0              323951    8.0500     M
# 184          male   1.00      2      1              230136   39.0000     F
# 249          male  37.00      1      1               11751   52.5542     D
# 22           male  34.00      0      0              248698   13.0000     D
# 890          male  26.00      0      0              111369   30.0000     C
# 163          male  26.00      0      0              347068    7.7750     M
# 226          male  22.00      0      0             PP 4348    9.3500     M
# 734          male  23.00      0      0               28425   13.0000     M
# 379          male  20.00      0      0                2648    4.0125     M
# 75           male  32.00      0      0                1601   56.4958     M
# 409          male  21.00      0      0              312992    7.7750     M
#
#             Embarked  AgeEncoded  SexEncoded  SexEncoded_1  SexEncoded_2  \
# PassengerId
# 846                S           2           2           0.0           1.0
# 747                S           2           2           0.0           1.0
# 309                C           2           2           0.0           1.0
# 366                S           2           2           0.0           1.0
# 402                S           2           2           0.0           1.0
# 208                C           2           2           0.0           1.0
# 811                S           2           2           0.0           1.0
# 841                S           2           2           0.0           1.0
# 785                S           2           2           0.0           1.0
# 211                S           2           2           0.0           1.0
# 5                  S           2           2           0.0           1.0
# 306                S           1           2           0.0           1.0
# 835                S           2           2           0.0           1.0
# 461                S           2           2           0.0           1.0
# 147                S           2           2           0.0           1.0
# 851                S           1           2           0.0           1.0
# 14                 S           2           2           0.0           1.0
# 92                 S           2           2           0.0           1.0
# 145                S           2           2           0.0           1.0
# 807                S           2           2           0.0           1.0
# 354                S           2           2           0.0           1.0
# 494                C           3           2           0.0           1.0
# 364                S           2           2           0.0           1.0
# 262                S           1           2           0.0           1.0
# 183                S           1           2           0.0           1.0
# 245                C           2           2           0.0           1.0
# 834                S           2           2           0.0           1.0
# 207                S           2           2           0.0           1.0
# 662                C           2           2           0.0           1.0
# 758                S           2           2           0.0           1.0
# 871                S           2           2           0.0           1.0
# 884                S           2           2           0.0           1.0
# 763                C           2           2           0.0           1.0
# 631                S           3           2           0.0           1.0
# 113                S           2           2           0.0           1.0
# 151                S           2           2           0.0           1.0
# 169                S           0           2           0.0           1.0
# 119                C           2           2           0.0           1.0
# 544                S           2           2           0.0           1.0
# 373                S           2           2           0.0           1.0
# 184                S           1           2           0.0           1.0
# 249                S           2           2           0.0           1.0
# 22                 S           2           2           0.0           1.0
# 890                C           2           2           0.0           1.0
# 163                S           2           2           0.0           1.0
# 226                S           2           2           0.0           1.0
# 734                S           2           2           0.0           1.0
# 379                C           2           2           0.0           1.0
# 75                 S           2           2           0.0           1.0
# 409                S           2           2           0.0           1.0
#
#                    Surename              Family
# PassengerId
# 846                  abbing          abbing_3_S
# 747                  abbott          abbott_3_S
# 309                 abelson         abelson_2_C
# 366                   adahl           adahl_3_S
# 402                   adams           adams_3_S
# 208                albimona        albimona_3_C
# 811               alexander       alexander_3_S
# 841                alhomaki        alhomaki_3_S
# 785                     ali             ali_3_S
# 211                     ali             ali_3_S
# 5                     allen           allen_3_S
# 306                 allison         allison_1_S
# 835                   allum           allum_3_S
# 461                anderson        anderson_1_S
# 147               andersson       andersson_3_S
# 851               andersson       andersson_3_S
# 14                andersson       andersson_3_S
# 92               andreasson      andreasson_3_S
# 145                  andrew          andrew_2_S
# 807                 andrews         andrews_1_S
# 354          arnold-franchi  arnold-franchi_3_S
# 494            artagaveytia    artagaveytia_1_C
# 364                    asim            asim_3_S
# 262                 asplund         asplund_3_S
# 183                 asplund         asplund_3_S
# 245                 attalah         attalah_3_C
# 834              augustsson      augustsson_3_S
# 207               backstrom       backstrom_3_S
# 662                    badt            badt_3_C
# 758                  bailey          bailey_2_S
# 871                  balkic          balkic_3_S
# 884                banfield        banfield_2_S
# 763                   barah           barah_3_C
# 631               barkworth       barkworth_1_S
# 113                  barton          barton_3_S
# 151                 bateman         bateman_2_S
# 169                 baumann         baumann_1_S
# 119                  baxter          baxter_1_C
# 544                   beane           beane_2_S
# 373                  beavan          beavan_3_S
# 184                  becker          becker_2_S
# 249                beckwith        beckwith_1_S
# 22                  beesley         beesley_2_S
# 890                    behr            behr_1_C
# 163               bengtsson       bengtsson_3_S
# 226                berglund        berglund_3_S
# 734                berriman        berriman_2_S
# 379                  betros          betros_3_C
# 75                     bing            bing_3_S
# 409               birkeland       birkeland_3_S

# %%
combined_df['Cabin'].fillna('M', inplace=True)
combined_df['Cabin'] = combined_df['Cabin'].astype(str).str[0]

# %% [markdown]
# ## generate family survive rate

# %%
def generate_family_survive_rate(x):
    x_filtered = x[(x['Sex'] == 'female') | (x['AgeEncoded'] == 1)]
    if x_filtered.shape[0] >= 1:
        return np.mean(x_filtered['Survived'])
    else:
        return None

# %%
def cal_dataframe_survive_rate(df):
    family_survive_rate = df.groupby('Family').apply(lambda x: generate_family_survive_rate(x)).to_frame()
    family_survive_rate.reset_index(inplace=True)
    family_survive_rate.columns = ['Family', 'Familay_Survive_Rate']
    return family_survive_rate

# %%
family_survive_rate = cal_dataframe_survive_rate(combined_df)
temp3 = combined_df.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
combined_df['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Familay_Survive_Rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-50ef7853a833> in <module>
#       1 family_survive_rate = cal_dataframe_survive_rate(combined_df)
#       2 temp3 = combined_df.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
# ----> 3 combined_df['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Familay_Survive_Rate'

# %%
combined_df[combined_df['Familay_Survive_Rate'] == 0].sort_values('Ticket')[:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 118               0.0       2
# 42                0.0       2
# 358               0.0       2
# 855               0.0       2
# 250               0.0       2
# 200               0.0       2
# 1041              NaN       2
# 313               0.0       2
# 115               0.0       3
# 599               0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 118                            Turpin, Mr. William John Robert    male  29.0
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0
# 358                                  Funk, Miss. Annie Clemmer  female  38.0
# 855              Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0
# 250                              Carter, Rev. Ernest Courtenay    male  54.0
# 200                     Yrois, Miss. Henriette ("Mrs Harbeck")  female  24.0
# 1041                                    Lahtinen, Rev. William    male  30.0
# 313                      Lahtinen, Mrs. William (Anna Sylfven)  female  26.0
# 115                                      Attalah, Miss. Malake  female  17.0
# 599                                          Boulos, Mr. Hanna    male   NaN
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked  AgeEncoded  \
# PassengerId
# 118              1      0   11668  21.0000   NaN        S           2
# 42               1      0   11668  21.0000   NaN        S           2
# 358              0      0  237671  13.0000   NaN        S           2
# 855              1      0  244252  26.0000   NaN        S           2
# 250              1      0  244252  26.0000   NaN        S           2
# 200              0      0  248747  13.0000   NaN        S           2
# 1041             1      1  250651  26.0000   NaN        S           2
# 313              1      1  250651  26.0000   NaN        S           2
# 115              0      0    2627  14.4583   NaN        C           2
# 599              0      0    2664   7.2250   NaN        C           0
#
#              SexEncoded  Surename        Family  Familay_Survive_Rate
# PassengerId
# 118                   2    turpin    turpin_2_S                   0.0
# 42                    1    turpin    turpin_2_S                   0.0
# 358                   1      funk      funk_2_S                   0.0
# 855                   1    carter    carter_2_S                   0.0
# 250                   2    carter    carter_2_S                   0.0
# 200                   1     yrois     yrois_2_S                   0.0
# 1041                  2  lahtinen  lahtinen_2_S                   0.0
# 313                   1  lahtinen  lahtinen_2_S                   0.0
# 115                   1   attalah   attalah_3_C                   0.0
# 599                   2    boulos    boulos_3_C                   0.0

# %% [markdown]
# # decison rules:
#
# 1) male
#
#     child NO => Die
#
#     child Yes => family rate? follow family rate
#
#     => Die
#
# 2) female
#
#     family rate? follow family rate
#
#     Survive

# %%
def gender_family_model(x, family_survive_column="Familay_Survive_Rate"):
    if x['Sex'] == 'female':
        if x[family_survive_column] >= 0 and x[family_survive_column] <= 0.5:
                return 0
        return 1
    else:
        if x['AgeEncoded'] == 1:
            if x[family_survive_column] > 0.5:
                return 1
            else:
                return 0
        else:
            return 0

# %% [markdown]
# # Cross Validation

# %%
kf3 = KFold(n_splits=5, shuffle=True)
original_train_df = combined_df.head(train_size)
accuracies = []

for tune_train_index, tune_test_index in kf3.split(original_train_df):
    X_train = original_train_df.iloc[tune_train_index].copy()
    X_test = original_train_df.iloc[tune_test_index].copy()
    
    X_train.drop('Familay_Survive_Rate', inplace=True, axis=1)
    X_test.drop('Familay_Survive_Rate', inplace=True, axis=1)
    
    family_survive_rate = cal_dataframe_survive_rate(X_train)
    temp3 = X_test.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
    X_test['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values
    
    true_y = X_test['Survived'].values
    prediction_y = X_test.apply(lambda x: gender_family_model(x), axis=1).values
    accuracies.append(accuracy_score(true_y, prediction_y))
    print({"accuracy": accuracy_score(true_y, prediction_y)})

print("average accuracy:",  np.mean(accuracies))
# Out:
# {'accuracy': 0.8547486033519553}
# {'accuracy': 0.7865168539325843}
# {'accuracy': 0.8089887640449438}
# {'accuracy': 0.8595505617977528}
# {'accuracy': 0.8707865168539326}
# average accuracy: 0.8361182599962339

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_graphviz
from subprocess import call
from random import randrange


# Create the parameter grid based on the results of random search 
param_grid = {
    'max_depth' : [4],
    'n_estimators': [10, 20, 50, 100]
}

kf3 = KFold(n_splits=5, shuffle=True)
original_train_df = combined_df.head(train_size)
accuracies = []

for params in ParameterGrid(param_grid):
    for tune_train_index, tune_test_index in kf3.split(original_train_df):
        X_train = original_train_df.iloc[tune_train_index].copy()
        X_test = original_train_df.iloc[tune_test_index].copy()

        X_train.drop('Familay_Survive_Rate', inplace=True, axis=1)
        X_test.drop('Familay_Survive_Rate', inplace=True, axis=1)

        family_survive_rate = cal_dataframe_survive_rate(X_train)
        temp2 = X_train.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
        X_train['Familay_Survive_Rate'] = temp2['Familay_Survive_Rate'].values
        X_train['Familay_Survive_Rate'].fillna(np.mean(X_train['Familay_Survive_Rate']), inplace=True)

        print(X_train['Familay_Survive_Rate'].describe())
        
        temp3 = X_test.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
        X_test['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values
        X_test['Familay_Survive_Rate'].fillna(np.mean(X_train['Familay_Survive_Rate']), inplace=True)

        rf_model = RandomForestClassifier(random_state=31, max_depth=params['max_depth'], n_estimators=params['n_estimators'])
        rf_model.fit(X_train[['SexEncoded_1','SexEncoded_2','AgeEncoded','Familay_Survive_Rate']], X_train['Survived'])

        print(X_test[['SexEncoded','AgeEncoded','Familay_Survive_Rate']].apply(lambda x: x.isna().sum()))
        
        true_y = X_test['Survived'].values
        prediction_y = rf_model.predict(X_test[['SexEncoded_1','SexEncoded_2','AgeEncoded','Familay_Survive_Rate']])
        accuracies.append(accuracy_score(true_y, prediction_y))
#         print({"accuracy": accuracy_score(true_y, prediction_y)})

        export_graphviz(rf_model.estimators_[0],
                        out_file='tree.dot',
                        feature_names=['SexEncoded_1','SexEncoded_2','AgeEncoded','Familay_Survive_Rate'],
                        precision = 2,
                        filled=True,
                        rounded=True)
    
        call(['/usr/local/bin/dot', '-Tpng', 'tree.dot', '-o', 'tree_{}_{}_{}.png'.format(params['max_depth'], params['n_estimators'], randrange(100)), '-Gdpi=600'])
        
    print({"average accuracy":  np.mean(accuracies),
          "params": params})
# Out:
# count    712.000000
# mean      -0.163858
# std        0.908190
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        1.000000
# max        1.000000
# Name: Familay_Survive_Rate, dtype: float64
# SexEncoded              0
# AgeEncoded              0
# Familay_Survive_Rate    0
# dtype: int64
# count    713.000000
# mean      -0.165498
# std        0.908543
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        1.000000
# max        1.000000
# Name: Familay_Survive_Rate, dtype: float64
# SexEncoded              0
# AgeEncoded              0
# Familay_Survive_Rate    0
# dtype: int64
# count    713.000000
# mean      -0.156522
# std        0.912213
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        1.000000
# max        1.000000
# Name: Familay_Survive_Rate, dtype: float64
# SexEncoded              0
# AgeEncoded              0
# Familay_Survive_Rate    0
# dtype: int64
# count    713.000000
# mean      -0.208575
# std        0.902490
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%        1.000000
# max        1.000000
# Name: Familay_Survive_Rate, dtype: float64
# SexEncoded              0
# AgeEncoded              0
# Familay_Survive_Rate    0
# dtype: int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-296ef0c00242> in <module>
#      54                         rounded=True)
#      55
# ---> 56         call(['/usr/local/bin/dot', '-Tpng', 'tree.dot', '-o', 'tree_{}_{}_{}.png'.format(params['max_depth'], params['n_estimators'], randrange(100)), '-Gdpi=600'])
#      57
#      58     print({"average accuracy":  np.mean(accuracies),
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in call(timeout, *popenargs, **kwargs)
#     340     with Popen(*popenargs, **kwargs) as p:
#     341         try:
# --> 342             return p.wait(timeout=timeout)
#     343         except:  # Including KeyboardInterrupt, wait handled that.
#     344             p.kill()
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in wait(self, timeout)
#    1077             endtime = _time() + timeout
#    1078         try:
# -> 1079             return self._wait(timeout=timeout)
#    1080         except KeyboardInterrupt:
#    1081             # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1802                         if self.returncode is not None:
#    1803                             break  # Another thread waited.
# -> 1804                         (pid, sts) = self._try_wait(0)
#    1805                         # Check the pid and loop as waitpid has been known to
#    1806                         # return 0 even without WNOHANG in odd situations.
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1760             """All callers to this function MUST hold self._waitpid_lock."""
#    1761             try:
# -> 1762                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1763             except ChildProcessError:
#    1764                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
import sys
print(sys.path)
sys.path.append('/usr/local/bin/')
# Out:
# ['/Users/yanxu/Documents/kaggles', '/Users/yanxu/Documents/kaggles/Titanic', '/Users/yanxu/opt/anaconda3/lib/python38.zip', '/Users/yanxu/opt/anaconda3/lib/python3.8', '/Users/yanxu/opt/anaconda3/lib/python3.8/lib-dynload', '', '/Users/yanxu/opt/anaconda3/lib/python3.8/site-packages', '/Users/yanxu/opt/anaconda3/lib/python3.8/site-packages/aeosa', '/Users/yanxu/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/Users/yanxu/.ipython', '/usr/local/bin/']

# %% [markdown]
# # Simple Gender + Family Model (Training)

# %%
true_y = combined_df.head(train_size)['Survived'].values
prediction_y = combined_df.head(train_size).apply(lambda x: gender_family_model(x), axis=1)
print(accuracy_score(true_y, prediction_y))

# %%
combined_df.groupby(['Sex', 'Survived']).agg({'Survived': ['mean', 'count']})

# %% [markdown]
# # Prediction

# %%
combined_df['Prediction'] = combined_df.apply(lambda x: gender_family_model(x), axis=1)

# %%
combined_df.tail()
# Out:
#              Survived  Pclass                          Name     Sex   Age  \
# PassengerId
# 1305              NaN       3            Spector, Mr. Woolf    male   NaN
# 1306              NaN       1  Oliva y Ocana, Dona. Fermina  female  39.0
# 1307              NaN       3  Saether, Mr. Simon Sivertsen    male  38.5
# 1308              NaN       3           Ware, Mr. Frederick    male   NaN
# 1309              NaN       3      Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
#              AgeEncoded       Surename             Family Familay_Type  \
# PassengerId
# 1305                  0        spector        spector_3_3          XXM
# 1306                  2  oliva y ocana  oliva y ocana_1_1          XFX
# 1307                  2        saether        saether_3_3          XXM
# 1308                  0           ware           ware_3_3          XXM
# 1309                  0          peter          peter_3_3          XFM
#
#              Familay_Survive_Rate  Prediction
# PassengerId
# 1305                         -1.0           0
# 1306                          NaN           1
# 1307                         -1.0           0
# 1308                         -1.0           0
# 1309                          1.0           0

# %%
true_y = combined_df.head(train_size)['Survived'].values
prediction_y = combined_df.head(train_size)['Prediction'].values
print(accuracy_score(true_y, prediction_y))
# Out:
# 0.8978675645342312

# %%
combined_df.head(train_size).groupby(['Sex','Survived']).agg({'Survived': ['mean', 'count']})
# Out:
#                 Survived
#                     mean count
# Sex    Survived
# female 0.0           0.0    81
#        1.0           1.0   233
# male   0.0           0.0   468
#        1.0           1.0   109

# %%
combined_df.head(train_size).groupby(['Sex','Prediction']).agg({'Prediction': ['mean', 'count']})
# Out:
#                   Prediction
#                         mean count
# Sex    Prediction
# female 0                   0    82
#        1                   1   232
# male   0                   0   556
#        1                   1    21

# %%
combined_df.head(train_size).shape
# Out:
# (891, 17)

# %%
combined_df.tail(test_size).groupby(['Sex','Prediction']).agg({'Prediction': ['mean', 'count']})
# Out:
#                   Prediction
#                         mean count
# Sex    Prediction
# female 0                   0    10
#        1                   1   142
# male   0                   0   257
#        1                   1     9

# %%
combined_df[combined_df['Ticket'] == '3701']
# Out:
#              Survived  Pclass                Name   Sex   Age  SibSp  Parch  \
# PassengerId
# 1044              NaN       3  Storey, Mr. Thomas  male  60.5      0      0
#
#             Ticket  Fare Cabin Embarked  AgeEncoded Surename      Family  \
# PassengerId
# 1044          3701   NaN   NaN        S           3   storey  storey_3_3
#
#             Familay_Type  Familay_Survive_Rate  Prediction
# PassengerId
# 1044                 XXM                  -1.0           0

# %% [markdown]
# # submission

# %%
temp1 = combined_df.tail(test_size)
temp1['PassengerId'] = temp1.index
tremp2 = temp1[['PassengerId','Prediction']]
tremp2.columns = ['PassengerId','Survived']
tremp2[['PassengerId', 'Survived']].to_csv("random_forest_submission_gender_family_model_v7.csv", index=False)
# Out:
# <ipython-input-45-f9ba093e3aab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp1['PassengerId'] = temp1.index

# %%
tremp2
# Out:
#              PassengerId  Survived
# PassengerId
# 892                  892         0
# 893                  893         1
# 894                  894         0
# 895                  895         0
# 896                  896         1
# ...                  ...       ...
# 1305                1305         0
# 1306                1306         1
# 1307                1307         0
# 1308                1308         0
# 1309                1309         0
#
# [418 rows x 2 columns]
