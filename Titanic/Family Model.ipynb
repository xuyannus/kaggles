# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../'))

# %%
import math
import common 
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
train_df = pd.read_csv("./data/train.csv", index_col="PassengerId")
test_df = pd.read_csv("./data/test.csv", index_col="PassengerId")

# %%
train_size = train_df.shape[0]
test_size = test_df.shape[0]

# %%
combined_df = pd.concat([train_df, test_df])

# %% [markdown]
# # Generate Female + Children Related Features

# %%
def age_encoding(x):
    if x is np.nan or x is None or math.isnan(x):
        return 0
        
    elif x <= 15: 
        return 1
    elif x > 60:
        return 3
    else:
        return 2
    
combined_df['AgeEncoded'] = combined_df['Age'].map(age_encoding)

# %% [markdown]
# ## generate family type

# %%
def extract_surename(x):
    return x.split(",")[0].strip().lower()
combined_df['Surename'] = combined_df['Name'].apply(lambda x: extract_surename(x))

# %%
def get_family_id(x):
    return "{}_{}_{}".format(x['Surename'], x['Pclass'], x['Embarked'])
combined_df['Family'] = combined_df.apply(lambda x: get_family_id(x), axis=1)

# %%
combined_df['Family'].value_counts()
# Out:
# andersson_3_S    11
# sage_3_S         11
# goodwin_3_S       8
# asplund_3_S       8
# panula_3_S        6
#                  ..
# maenpaa_3_S       1
# hedman_3_S        1
# hoyt_1_C          1
# lindblom_3_S      1
# heikkinen_3_S     1
# Name: Family, Length: 915, dtype: int64

# %%
def generate_family_type(x):
    familay_type = ""
    
    if 1 in x['AgeEncoded'].values:
        familay_type += 'C'
    else:
        familay_type += 'X'
        
    if 'female' in x[x['AgeEncoded'] != 1]['Sex'].values:
        familay_type += 'F'
    else:
        familay_type += 'X'
        
    if 'male' in x[x['AgeEncoded'] != 1]['Sex'].values:
        familay_type += 'M'
    else:
        familay_type += 'X'
    return familay_type

# %%
family_type = combined_df.groupby('Family').apply(lambda x: generate_family_type(x)).to_frame()

# %%
family_type.reset_index(inplace=True)
family_type.columns = ['Family', 'Familay_Type']

# %%
combined_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              AgeEncoded   Surename         Family
# PassengerId
# 1                     2     braund     braund_3_S
# 2                     2    cumings    cumings_1_C
# 3                     2  heikkinen  heikkinen_3_S
# 4                     2   futrelle   futrelle_1_S
# 5                     2      allen      allen_3_S

# %%
if 'Familay_Type' in combined_df.columns:
    combined_df.drop('Familay_Type', inplace=True, axis=1)
temp2 = combined_df.merge(family_type, left_on='Family', right_on='Family', how='left')

# %%
temp2.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0       3                            Braund, Mr. Owen Harris
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0       3                             Heikkinen, Miss. Laina
# 3       1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    AgeEncoded   Surename         Family Familay_Type
# 0           2     braund     braund_3_S          XXM
# 1           2    cumings    cumings_1_C          XFM
# 2           2  heikkinen  heikkinen_3_S          XFX
# 3           2   futrelle   futrelle_1_S          XFM
# 4           2      allen      allen_3_S          XXM

# %%
combined_df.loc[:, 'Familay_Type'] = temp2['Familay_Type'].values

# %%
combined_df.groupby('Familay_Type')['Familay_Type'].count()
# Out:
# Familay_Type
# CFM    149
# CFX     58
# CXM     25
# CXX      9
# XFM    274
# XFX    203
# XXM    591
# Name: Familay_Type, dtype: int64

# %% [markdown]
# ## generate family survive rate

# %%
def generate_family_survive_rate(x):
    x_filtered = x[(x['Sex'] == 'female') | (x['AgeEncoded'] == 1)]
    if x_filtered.shape[0] >= 1:
        return np.mean(x_filtered['Survived'])
    else:
        return -1

# %%
def cal_dataframe_survive_rate(df):
    family_survive_rate = df.groupby('Family').apply(lambda x: generate_family_survive_rate(x)).to_frame()
    family_survive_rate.reset_index(inplace=True)
    family_survive_rate.columns = ['Family', 'Familay_Survive_Rate']
    return family_survive_rate

# %%
family_survive_rate = cal_dataframe_survive_rate(combined_df)
temp3 = combined_df.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
combined_df['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values

# %%
combined_df[combined_df['Familay_Survive_Rate'] == 0].sort_values('Ticket')[:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 118               0.0       2
# 42                0.0       2
# 358               0.0       2
# 855               0.0       2
# 250               0.0       2
# 200               0.0       2
# 1041              NaN       2
# 313               0.0       2
# 115               0.0       3
# 599               0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 118                            Turpin, Mr. William John Robert    male  29.0
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0
# 358                                  Funk, Miss. Annie Clemmer  female  38.0
# 855              Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0
# 250                              Carter, Rev. Ernest Courtenay    male  54.0
# 200                     Yrois, Miss. Henriette ("Mrs Harbeck")  female  24.0
# 1041                                    Lahtinen, Rev. William    male  30.0
# 313                      Lahtinen, Mrs. William (Anna Sylfven)  female  26.0
# 115                                      Attalah, Miss. Malake  female  17.0
# 599                                          Boulos, Mr. Hanna    male   NaN
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked  AgeEncoded  \
# PassengerId
# 118              1      0   11668  21.0000   NaN        S           2
# 42               1      0   11668  21.0000   NaN        S           2
# 358              0      0  237671  13.0000   NaN        S           2
# 855              1      0  244252  26.0000   NaN        S           2
# 250              1      0  244252  26.0000   NaN        S           2
# 200              0      0  248747  13.0000   NaN        S           2
# 1041             1      1  250651  26.0000   NaN        S           2
# 313              1      1  250651  26.0000   NaN        S           2
# 115              0      0    2627  14.4583   NaN        C           2
# 599              0      0    2664   7.2250   NaN        C           0
#
#              Surename        Family Familay_Type  Familay_Survive_Rate
# PassengerId
# 118            turpin    turpin_2_S          XFM                   0.0
# 42             turpin    turpin_2_S          XFM                   0.0
# 358              funk      funk_2_S          XFX                   0.0
# 855            carter    carter_2_S          XFM                   0.0
# 250            carter    carter_2_S          XFM                   0.0
# 200             yrois     yrois_2_S          XFX                   0.0
# 1041         lahtinen  lahtinen_2_S          XFM                   0.0
# 313          lahtinen  lahtinen_2_S          XFM                   0.0
# 115           attalah   attalah_3_C          XFM                   0.0
# 599            boulos    boulos_3_C          CFM                   0.0

# %% [markdown]
# # decison rules:
#
# 1) male
#
#     child NO => Die
#
#     child Yes => family rate? follow family rate
#
#     => Die
#
# 2) female
#
#     family rate? follow family rate
#
#     Survive

# %%
def gender_family_model(x, family_survive_column="Familay_Survive_Rate"):
    if x['Sex'] == 'female':
        if x[family_survive_column] >= 0 and x[family_survive_column] <= 0.5:
                return 0
        return 1
    else:
        if x['AgeEncoded'] == 1:
            if x[family_survive_column] > 0.5:
                return 1
            else:
                return 0
        else:
            return 0

# %% [markdown]
# # Cross Validation

# %%
kf3 = KFold(n_splits=3, shuffle=False)

for tune_train_index, tune_test_index in kf3.split(combined_df):
    X_train = combined_df.iloc[tune_train_index].copy()
    X_test = combined_df.iloc[tune_test_index].copy()
    
    family_survive_rate = cal_dataframe_survive_rate(X_train)
    temp3 = X_test.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
    X_test['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values
    
    true_y = X_test['Survived'].values
    prediction_y = X_test.apply(lambda x: gender_family_model(x), axis=1)
    print(accuracy_score(true_y, prediction_y))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Familay_Survive_Rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-823c4a564a42> in <module>
#       5     X_test = combined_df.iloc[tune_test_index].copy()
#       6
# ----> 7     family_survive_rate = cal_dataframe_survive_rate(X_train)
#       8     temp3 = X_test.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
#       9     X_test['Familay_Survive_Rate'] = temp3['Familay_Survive_Rate'].values
#
# <ipython-input-19-fea45f27519d> in cal_dataframe_survive_rate(df)
#       4     family_survive_rate.columns = ['Family', 'Familay_Survive_Rate']
#       5     temp3 = df.merge(family_survive_rate, left_on='Family', right_on='Family', how='left')
# ----> 6     return temp3['Familay_Survive_Rate'].values
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Familay_Survive_Rate'

# %%
true_y = combined_df.head(train_size)['Survived'].values
prediction_y = combined_df.head(train_size).apply(lambda x: 1 if x['Sex'] == 'female' else 0, axis=1)
print(accuracy_score(true_y, prediction_y))
# Out:
# 0.7867564534231201

# %% [markdown]
# # Simple Gender + Family Model (Training)

# %%
true_y = combined_df.head(train_size)['Survived'].values
prediction_y = combined_df.head(train_size).apply(lambda x: gender_family_model(x), axis=1)
print(accuracy_score(true_y, prediction_y))
# Out:
# 0.8978675645342312

# %%
combined_df.groupby(['Sex', 'Survived']).agg({'Survived': ['mean', 'count']})
# Out:
#                 Survived
#                     mean count
# Sex    Survived
# female 0.0           0.0    81
#        1.0           1.0   233
# male   0.0           0.0   468
#        1.0           1.0   109

# %% [markdown]
# # Prediction

# %%
combined_df['Prediction'] = combined_df.apply(lambda x: gender_family_model(x), axis=1)

# %%
combined_df.tail()
# Out:
#              Survived  Pclass                          Name     Sex   Age  \
# PassengerId
# 1305              NaN       3            Spector, Mr. Woolf    male   NaN
# 1306              NaN       1  Oliva y Ocana, Dona. Fermina  female  39.0
# 1307              NaN       3  Saether, Mr. Simon Sivertsen    male  38.5
# 1308              NaN       3           Ware, Mr. Frederick    male   NaN
# 1309              NaN       3      Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
#              AgeEncoded       Surename             Family Familay_Type  \
# PassengerId
# 1305                  0        spector        spector_3_3          XXM
# 1306                  2  oliva y ocana  oliva y ocana_1_1          XFX
# 1307                  2        saether        saether_3_3          XXM
# 1308                  0           ware           ware_3_3          XXM
# 1309                  0          peter          peter_3_3          XFM
#
#              Familay_Survive_Rate  Prediction
# PassengerId
# 1305                         -1.0           0
# 1306                          NaN           1
# 1307                         -1.0           0
# 1308                         -1.0           0
# 1309                          1.0           0

# %%
true_y = combined_df.head(train_size)['Survived'].values
prediction_y = combined_df.head(train_size)['Prediction'].values
print(accuracy_score(true_y, prediction_y))
# Out:
# 0.8978675645342312

# %%
combined_df.head(train_size).groupby(['Sex','Survived']).agg({'Survived': ['mean', 'count']})
# Out:
#                 Survived
#                     mean count
# Sex    Survived
# female 0.0           0.0    81
#        1.0           1.0   233
# male   0.0           0.0   468
#        1.0           1.0   109

# %%
combined_df.head(train_size).groupby(['Sex','Prediction']).agg({'Prediction': ['mean', 'count']})
# Out:
#                   Prediction
#                         mean count
# Sex    Prediction
# female 0                   0    82
#        1                   1   232
# male   0                   0   556
#        1                   1    21

# %%
combined_df.head(train_size).shape
# Out:
# (891, 17)

# %%
combined_df.tail(test_size).groupby(['Sex','Prediction']).agg({'Prediction': ['mean', 'count']})
# Out:
#                   Prediction
#                         mean count
# Sex    Prediction
# female 0                   0    10
#        1                   1   142
# male   0                   0   257
#        1                   1     9

# %%
combined_df[combined_df['Ticket'] == '3701']
# Out:
#              Survived  Pclass                Name   Sex   Age  SibSp  Parch  \
# PassengerId
# 1044              NaN       3  Storey, Mr. Thomas  male  60.5      0      0
#
#             Ticket  Fare Cabin Embarked  AgeEncoded Surename      Family  \
# PassengerId
# 1044          3701   NaN   NaN        S           3   storey  storey_3_3
#
#             Familay_Type  Familay_Survive_Rate  Prediction
# PassengerId
# 1044                 XXM                  -1.0           0

# %% [markdown]
# # submission

# %%
temp1 = combined_df.tail(test_size)
temp1['PassengerId'] = temp1.index
tremp2 = temp1[['PassengerId','Prediction']]
tremp2.columns = ['PassengerId','Survived']
tremp2[['PassengerId', 'Survived']].to_csv("random_forest_submission_gender_family_model_v7.csv", index=False)
# Out:
# <ipython-input-45-f9ba093e3aab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp1['PassengerId'] = temp1.index

# %%
tremp2
# Out:
#              PassengerId  Survived
# PassengerId
# 892                  892         0
# 893                  893         1
# 894                  894         0
# 895                  895         0
# 896                  896         1
# ...                  ...       ...
# 1305                1305         0
# 1306                1306         1
# 1307                1307         0
# 1308                1308         0
# 1309                1309         0
#
# [418 rows x 2 columns]
